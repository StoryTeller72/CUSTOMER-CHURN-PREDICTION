# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, cross_val_predict, StratifiedKFold, cross_validate
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, make_scorer
import mlflow
from mlflow import sklearn, lightgbm, catboost, xgboost

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

import optuna

import json

import shap

# %% [markdown]
# # Logistic regression (baseLine)

# %%
data = pd.read_csv(r"..\data/preprocessed_dummy_Data.csv",)
X, y = data.drop(['Churn'], axis=1), data['Churn']

# %% [markdown]
# ## Simple Solution

# %%
mlflow.set_experiment("Customer_Churn")

scoring = ['roc_auc', 'f1', 'precision', 'recall']

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(class_weight='balanced', random_state=42))
])

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name="basicRegression"):
    mlflow.log_param("model", "base_LogisticRegression")
    mlflow.log_param("class_weight", "balanced")
    mlflow.log_param("solver", "lbfgs")
    
    scores = cross_validate(pipeline, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    pipeline.fit(X, y)
    mlflow.sklearn.log_model(pipeline, "logreg_pipeline")

pd.DataFrame(scores)
# Out:
# 2025/11/22 00:01:34 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# roc_auc: mean=0.843
# f1: mean=0.627
# precision: mean=0.518
# recall: mean=0.795
# 2025/11/22 00:01:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  0.020065    0.011959      0.852043  0.637712        0.528070     0.804813
# 1  0.020740    0.013401      0.843039  0.632885        0.516020     0.818182
# 2  0.020372    0.012727      0.861283  0.643312        0.533451     0.810160
# 3  0.014724    0.013213      0.823568  0.604255        0.500882     0.761394
# 4  0.022254    0.014383      0.833918  0.618491        0.513228     0.778075

# %% [markdown]
# ## Tuned logistic regression

# %%
def objective(trial):
   
    C = trial.suggest_float('C', 1, 100, log=True)   
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
       # Подбор class_weight
    cw_option = trial.suggest_categorical('class_weight_option', ['none', 'balanced', 'custom'])
    if cw_option == 'none':
        class_weight = None
    elif cw_option == 'balanced':
        class_weight = 'balanced'
    else:
        # пример: w0=1, w1=trial от 1 до 5
        w1 = trial.suggest_float('custom_weight_1', 1.0, 5.0)
        class_weight = {0: 1.0, 1: w1}
        
    solver = 'liblinear' if penalty == 'l1' else 'lbfgs'   
    
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('logreg', LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=1000, random_state=42, class_weight=class_weight))
    ])
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    scores = cross_val_score(pipeline, X, y, cv=skf, scoring='f1')
    
    return scores.mean()

# %%
study = optuna.create_study(direction='maximize')  
study.optimize(objective, n_trials=50)
# Out:
# [I 2025-11-22 00:02:57,029] A new study created in memory with name: no-name-ac8e653e-3a82-4ac1-9927-81d9d84b9a6b
# [I 2025-11-22 00:02:57,157] Trial 0 finished with value: 0.6290853121290508 and parameters: {'C': 13.345390679424492, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.2733392861708563}. Best is trial 0 with value: 0.6290853121290508.
# [I 2025-11-22 00:02:57,284] Trial 1 finished with value: 0.626523267087044 and parameters: {'C': 2.617578009107284, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 0 with value: 0.6290853121290508.
# [I 2025-11-22 00:02:57,424] Trial 2 finished with value: 0.6274086607587737 and parameters: {'C': 64.11682505892446, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 0 with value: 0.6290853121290508.
# [I 2025-11-22 00:02:57,547] Trial 3 finished with value: 0.5948594219389023 and parameters: {'C': 40.65587062266152, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 0 with value: 0.6290853121290508.
# [I 2025-11-22 00:02:57,676] Trial 4 finished with value: 0.6221907387150194 and parameters: {'C': 25.57466044875322, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.8034069917011264}. Best is trial 0 with value: 0.6290853121290508.
# [I 2025-11-22 00:03:01,099] Trial 5 finished with value: 0.6294807263165868 and parameters: {'C': 72.63565249636997, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.4035015466682363}. Best is trial 5 with value: 0.6294807263165868.
# [I 2025-11-22 00:03:04,136] Trial 6 finished with value: 0.5944843828723327 and parameters: {'C': 50.014104411468516, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 5 with value: 0.6294807263165868.
# [I 2025-11-22 00:03:04,265] Trial 7 finished with value: 0.6274086607587737 and parameters: {'C': 85.34441931390494, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6294807263165868.
# [I 2025-11-22 00:03:05,126] Trial 8 finished with value: 0.6266361240015124 and parameters: {'C': 1.053958775625725, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6294807263165868.
# [I 2025-11-22 00:03:06,588] Trial 9 finished with value: 0.6300802129026972 and parameters: {'C': 1.7330413797167055, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.0944938567091924}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:10,134] Trial 10 finished with value: 0.5992061575071822 and parameters: {'C': 4.167505088958951, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 4.723623266490085}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:13,622] Trial 11 finished with value: 0.6239038844947336 and parameters: {'C': 9.37232035158283, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.009197032612504}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:14,989] Trial 12 finished with value: 0.6229001386147744 and parameters: {'C': 1.1012192837545622, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.0607054477921185}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:17,990] Trial 13 finished with value: 0.5992888363518811 and parameters: {'C': 5.664415962501539, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.0668102737450083}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:21,329] Trial 14 finished with value: 0.6278141985003857 and parameters: {'C': 20.655407120886863, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.264216595356525}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:24,124] Trial 15 finished with value: 0.6134511637904569 and parameters: {'C': 2.2312272735696483, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.654241347259381}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:27,097] Trial 16 finished with value: 0.5941176721605155 and parameters: {'C': 6.878249310594835, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:30,358] Trial 17 finished with value: 0.6195420620982939 and parameters: {'C': 17.183556946576005, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.522495307190951}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:32,520] Trial 18 finished with value: 0.6291205160921696 and parameters: {'C': 2.297263756711666, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.3548371790897633}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:35,474] Trial 19 finished with value: 0.5944866878691066 and parameters: {'C': 27.68126348904377, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:38,492] Trial 20 finished with value: 0.6123106222050142 and parameters: {'C': 3.301379519933527, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.7346195720076167}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:40,268] Trial 21 finished with value: 0.6299193228078149 and parameters: {'C': 1.7596428270542086, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.4101814630637093}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:41,962] Trial 22 finished with value: 0.6288213696732595 and parameters: {'C': 1.5066391147649096, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.596948207221179}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:43,444] Trial 23 finished with value: 0.621003215917429 and parameters: {'C': 1.791386638920165, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.70170075929371}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:46,914] Trial 24 finished with value: 0.6261137502592862 and parameters: {'C': 4.438951905138163, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.8155903623303815}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:50,379] Trial 25 finished with value: 0.625204383441767 and parameters: {'C': 8.578505756535527, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.9304323761758782}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:51,772] Trial 26 finished with value: 0.6290299978391785 and parameters: {'C': 1.5107628449207253, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.097018022948459}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:54,862] Trial 27 finished with value: 0.6168155139257548 and parameters: {'C': 12.184282973239624, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.3796980276645554}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:56,946] Trial 28 finished with value: 0.6270351663320529 and parameters: {'C': 3.157776597955492, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:03:57,069] Trial 29 finished with value: 0.5948594219389023 and parameters: {'C': 98.54933967646897, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:00,064] Trial 30 finished with value: 0.6158320179297785 and parameters: {'C': 14.463942588686562, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.4289032473141368}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:02,459] Trial 31 finished with value: 0.6279481495920486 and parameters: {'C': 2.2078255340170383, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.5064894363990424}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:03,912] Trial 32 finished with value: 0.6278543501410061 and parameters: {'C': 1.3370493951258324, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.520246976620076}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:06,060] Trial 33 finished with value: 0.6282436858642549 and parameters: {'C': 2.0645422978836767, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.2238865196185245}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:06,188] Trial 34 finished with value: 0.626523267087044 and parameters: {'C': 3.0354319612924114, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:06,311] Trial 35 finished with value: 0.6271455450830214 and parameters: {'C': 4.8986944549182745, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.7868237939005396}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:10,382] Trial 36 finished with value: 0.628317645696453 and parameters: {'C': 39.8379318014679, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.0157080914525443}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:10,517] Trial 37 finished with value: 0.594607965127283 and parameters: {'C': 2.6416625348794027, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:12,310] Trial 38 finished with value: 0.6273290333747219 and parameters: {'C': 1.799145483036155, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:13,755] Trial 39 finished with value: 0.6203146486571185 and parameters: {'C': 1.1259338687306444, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.1888268399279864}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:13,890] Trial 40 finished with value: 0.6278135760669995 and parameters: {'C': 66.26597082549044, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.5291757784252007}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:14,022] Trial 41 finished with value: 0.6278223397959884 and parameters: {'C': 29.364479841910228, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.2640230434026667}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:14,164] Trial 42 finished with value: 0.6284151469886823 and parameters: {'C': 59.665591070577385, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.3147542223316195}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:14,296] Trial 43 finished with value: 0.6268367751275921 and parameters: {'C': 36.846604903940865, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.7287792820737}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:14,431] Trial 44 finished with value: 0.6268157882510176 and parameters: {'C': 6.210594851759959, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:17,287] Trial 45 finished with value: 0.6206378156322652 and parameters: {'C': 3.876823645895457, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.7019268703905044}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:17,435] Trial 46 finished with value: 0.6226760233404373 and parameters: {'C': 20.954674164296318, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.892124214209244}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:18,946] Trial 47 finished with value: 0.5919979369120103 and parameters: {'C': 2.5486065818216743, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:22,927] Trial 48 finished with value: 0.5985183553835312 and parameters: {'C': 7.208343959172702, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 4.8448929081597365}. Best is trial 9 with value: 0.6300802129026972.
# [I 2025-11-22 00:04:26,392] Trial 49 finished with value: 0.6136988522878927 and parameters: {'C': 11.03804922387199, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.3396767404032377}. Best is trial 9 with value: 0.6300802129026972.

# %%
print("Best trial:")
trial = study.best_trial
print("  F1: {:.4f}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   F1: 0.6301
#   Params:
#     C: 1.7330413797167055
#     penalty: l1
#     class_weight_option: custom
#     custom_weight_1: 2.0944938567091924

# %%
mlflow.set_experiment("Customer_Churn")

scoring = ['roc_auc', 'f1', 'precision', 'recall']

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(class_weight={0: 1.0, 1: 2.1}, random_state=42, C=1.73, penalty='l1', solver='liblinear'))
])

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name='tunedRegression'):
    mlflow.log_param("model", "tuned_LogisticRegression")
    mlflow.log_param("class_weight", "custom, w2=2.1")
    mlflow.log_param("solver", "liblinear")
    mlflow.log_param("C", "1.73")
    mlflow.log_param("penalty", "L1")
    
    scores = cross_validate(pipeline, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    pipeline.fit(X, y)
    mlflow.sklearn.log_model(pipeline, "logreg_pipeline_tuned")

pd.DataFrame(scores)
# Out:
# roc_auc: mean=0.843
# f1: mean=0.629
# precision: mean=0.552
# recall: mean=0.732
# 2025/11/22 00:06:13 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/22 00:06:16 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  0.290849    0.012814      0.851715  0.651217        0.574642     0.751337
# 1  0.268429    0.011559      0.842871  0.627540        0.542969     0.743316
# 2  0.461974    0.016150      0.861562  0.655963        0.574297     0.764706
# 3  0.366043    0.016032      0.823892  0.604706        0.538784     0.689008
# 4  0.295056    0.013752      0.833970  0.606613        0.528827     0.711230

# %% [markdown]
# # Random Forest

# %%
def objective(trial):
   
    n_estimators = trial.suggest_int('n_estimators', 50, 1000, log=True)   
    max_depth = trial.suggest_int('max_depth', 5, 30)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 2, 50, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 50, log=True)
    cw_option = trial.suggest_categorical('class_weight_option', [None, 'balanced', 'balanced_subsample'])
    
    RF_clf = RandomForestClassifier(
        n_estimators=n_estimators, 
        max_depth=max_depth,
        min_samples_leaf=min_samples_leaf,
        min_samples_split=min_samples_split,
        class_weight=cw_option
        )
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    scores = cross_val_score(RF_clf, X, y, cv=skf, scoring='f1')
    
    return scores.mean()

# %%
RF_study = optuna.create_study(direction='maximize')  
RF_study.optimize(objective, n_trials=50)
# Out:
# [I 2025-11-22 01:01:48,778] A new study created in memory with name: no-name-cc5969b1-4647-4f35-aa40-d9bac355986a
# [I 2025-11-22 01:01:53,881] Trial 0 finished with value: 0.5763658037403031 and parameters: {'n_estimators': 252, 'max_depth': 9, 'min_samples_leaf': 13, 'min_samples_split': 16, 'class_weight_option': None}. Best is trial 0 with value: 0.5763658037403031.
# [I 2025-11-22 01:01:57,951] Trial 1 finished with value: 0.6338903691114053 and parameters: {'n_estimators': 158, 'max_depth': 29, 'min_samples_leaf': 27, 'min_samples_split': 3, 'class_weight_option': 'balanced_subsample'}. Best is trial 1 with value: 0.6338903691114053.
# [I 2025-11-22 01:02:18,741] Trial 2 finished with value: 0.6220953836156977 and parameters: {'n_estimators': 581, 'max_depth': 15, 'min_samples_leaf': 2, 'min_samples_split': 3, 'class_weight_option': 'balanced_subsample'}. Best is trial 1 with value: 0.6338903691114053.
# [I 2025-11-22 01:02:26,711] Trial 3 finished with value: 0.6348067869336094 and parameters: {'n_estimators': 353, 'max_depth': 28, 'min_samples_leaf': 14, 'min_samples_split': 34, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:02:35,365] Trial 4 finished with value: 0.5590278785483593 and parameters: {'n_estimators': 460, 'max_depth': 29, 'min_samples_leaf': 40, 'min_samples_split': 14, 'class_weight_option': None}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:02:47,867] Trial 5 finished with value: 0.6260350313358274 and parameters: {'n_estimators': 832, 'max_depth': 5, 'min_samples_leaf': 3, 'min_samples_split': 6, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:02:57,657] Trial 6 finished with value: 0.6211126706841744 and parameters: {'n_estimators': 310, 'max_depth': 24, 'min_samples_leaf': 3, 'min_samples_split': 4, 'class_weight_option': 'balanced_subsample'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:02,055] Trial 7 finished with value: 0.624313703961816 and parameters: {'n_estimators': 202, 'max_depth': 5, 'min_samples_leaf': 15, 'min_samples_split': 16, 'class_weight_option': 'balanced_subsample'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:06,016] Trial 8 finished with value: 0.6264677326471843 and parameters: {'n_estimators': 164, 'max_depth': 17, 'min_samples_leaf': 2, 'min_samples_split': 13, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:11,780] Trial 9 finished with value: 0.5748316020758644 and parameters: {'n_estimators': 272, 'max_depth': 21, 'min_samples_leaf': 10, 'min_samples_split': 2, 'class_weight_option': None}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:13,259] Trial 10 finished with value: 0.6330116660189303 and parameters: {'n_estimators': 68, 'max_depth': 24, 'min_samples_leaf': 6, 'min_samples_split': 39, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:14,918] Trial 11 finished with value: 0.6305626610519786 and parameters: {'n_estimators': 87, 'max_depth': 30, 'min_samples_leaf': 29, 'min_samples_split': 49, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:17,727] Trial 12 finished with value: 0.6327914517929294 and parameters: {'n_estimators': 112, 'max_depth': 26, 'min_samples_leaf': 21, 'min_samples_split': 28, 'class_weight_option': 'balanced_subsample'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:20,174] Trial 13 finished with value: 0.6317241393036326 and parameters: {'n_estimators': 135, 'max_depth': 20, 'min_samples_leaf': 42, 'min_samples_split': 6, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:21,687] Trial 14 finished with value: 0.6291787256048209 and parameters: {'n_estimators': 50, 'max_depth': 27, 'min_samples_leaf': 6, 'min_samples_split': 2, 'class_weight_option': 'balanced_subsample'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:31,936] Trial 15 finished with value: 0.6339784345536039 and parameters: {'n_estimators': 398, 'max_depth': 14, 'min_samples_leaf': 22, 'min_samples_split': 8, 'class_weight_option': 'balanced_subsample'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:41,544] Trial 16 finished with value: 0.6342831501982835 and parameters: {'n_estimators': 460, 'max_depth': 14, 'min_samples_leaf': 17, 'min_samples_split': 9, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:03:54,732] Trial 17 finished with value: 0.6332234482989515 and parameters: {'n_estimators': 575, 'max_depth': 12, 'min_samples_leaf': 7, 'min_samples_split': 25, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:04:26,668] Trial 18 finished with value: 0.6333861724954168 and parameters: {'n_estimators': 997, 'max_depth': 10, 'min_samples_leaf': 12, 'min_samples_split': 22, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:04:35,283] Trial 19 finished with value: 0.6328183508366909 and parameters: {'n_estimators': 381, 'max_depth': 19, 'min_samples_leaf': 18, 'min_samples_split': 10, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:04:50,933] Trial 20 finished with value: 0.6346401597645193 and parameters: {'n_estimators': 723, 'max_depth': 23, 'min_samples_leaf': 9, 'min_samples_split': 39, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:05:06,350] Trial 21 finished with value: 0.6342003562126529 and parameters: {'n_estimators': 674, 'max_depth': 23, 'min_samples_leaf': 8, 'min_samples_split': 31, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:05:16,683] Trial 22 finished with value: 0.631776863440568 and parameters: {'n_estimators': 473, 'max_depth': 17, 'min_samples_leaf': 4, 'min_samples_split': 46, 'class_weight_option': 'balanced'}. Best is trial 3 with value: 0.6348067869336094.
# [I 2025-11-22 01:05:32,504] Trial 23 finished with value: 0.6356365123008892 and parameters: {'n_estimators': 702, 'max_depth': 26, 'min_samples_leaf': 10, 'min_samples_split': 21, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:05:49,988] Trial 24 finished with value: 0.6329770986105694 and parameters: {'n_estimators': 809, 'max_depth': 26, 'min_samples_leaf': 10, 'min_samples_split': 34, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:06:05,977] Trial 25 finished with value: 0.6344461450462154 and parameters: {'n_estimators': 676, 'max_depth': 22, 'min_samples_leaf': 5, 'min_samples_split': 21, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:06:27,693] Trial 26 finished with value: 0.5721793891912574 and parameters: {'n_estimators': 964, 'max_depth': 27, 'min_samples_leaf': 10, 'min_samples_split': 20, 'class_weight_option': None}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:06:35,232] Trial 27 finished with value: 0.6338308199134262 and parameters: {'n_estimators': 355, 'max_depth': 25, 'min_samples_leaf': 13, 'min_samples_split': 37, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:06:47,245] Trial 28 finished with value: 0.6345141110605516 and parameters: {'n_estimators': 574, 'max_depth': 28, 'min_samples_leaf': 8, 'min_samples_split': 50, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:06:52,298] Trial 29 finished with value: 0.5763899718274907 and parameters: {'n_estimators': 232, 'max_depth': 19, 'min_samples_leaf': 13, 'min_samples_split': 17, 'class_weight_option': None}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:07:09,583] Trial 30 finished with value: 0.6324139218142 and parameters: {'n_estimators': 743, 'max_depth': 30, 'min_samples_leaf': 4, 'min_samples_split': 27, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:07:21,963] Trial 31 finished with value: 0.6351134106049227 and parameters: {'n_estimators': 576, 'max_depth': 28, 'min_samples_leaf': 8, 'min_samples_split': 43, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:07:34,349] Trial 32 finished with value: 0.6344126296419088 and parameters: {'n_estimators': 572, 'max_depth': 28, 'min_samples_leaf': 10, 'min_samples_split': 38, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:07:41,110] Trial 33 finished with value: 0.6323987991007405 and parameters: {'n_estimators': 309, 'max_depth': 25, 'min_samples_leaf': 7, 'min_samples_split': 40, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:07:50,557] Trial 34 finished with value: 0.6353802541435867 and parameters: {'n_estimators': 489, 'max_depth': 22, 'min_samples_leaf': 26, 'min_samples_split': 32, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:07:59,776] Trial 35 finished with value: 0.5623837523418775 and parameters: {'n_estimators': 482, 'max_depth': 29, 'min_samples_leaf': 32, 'min_samples_split': 29, 'class_weight_option': None}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:07,430] Trial 36 finished with value: 0.6321187000075672 and parameters: {'n_estimators': 404, 'max_depth': 28, 'min_samples_leaf': 35, 'min_samples_split': 12, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:13,678] Trial 37 finished with value: 0.6347776496752144 and parameters: {'n_estimators': 315, 'max_depth': 22, 'min_samples_leaf': 24, 'min_samples_split': 19, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:17,921] Trial 38 finished with value: 0.6342110959224382 and parameters: {'n_estimators': 199, 'max_depth': 26, 'min_samples_leaf': 17, 'min_samples_split': 32, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:31,159] Trial 39 finished with value: 0.5724778167322622 and parameters: {'n_estimators': 622, 'max_depth': 24, 'min_samples_leaf': 15, 'min_samples_split': 23, 'class_weight_option': None}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:40,193] Trial 40 finished with value: 0.6286194475925619 and parameters: {'n_estimators': 504, 'max_depth': 30, 'min_samples_leaf': 49, 'min_samples_split': 25, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:46,641] Trial 41 finished with value: 0.63525987228038 and parameters: {'n_estimators': 312, 'max_depth': 22, 'min_samples_leaf': 20, 'min_samples_split': 17, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:51,801] Trial 42 finished with value: 0.6340680771952405 and parameters: {'n_estimators': 263, 'max_depth': 21, 'min_samples_leaf': 26, 'min_samples_split': 15, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:08:58,956] Trial 43 finished with value: 0.6348832948074916 and parameters: {'n_estimators': 351, 'max_depth': 25, 'min_samples_leaf': 20, 'min_samples_split': 18, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:09:04,942] Trial 44 finished with value: 0.6352012154377809 and parameters: {'n_estimators': 295, 'max_depth': 23, 'min_samples_leaf': 20, 'min_samples_split': 17, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:09:08,624] Trial 45 finished with value: 0.6338711354831148 and parameters: {'n_estimators': 189, 'max_depth': 18, 'min_samples_leaf': 34, 'min_samples_split': 14, 'class_weight_option': 'balanced'}. Best is trial 23 with value: 0.6356365123008892.
# [I 2025-11-22 01:09:16,731] Trial 46 finished with value: 0.6359251851323043 and parameters: {'n_estimators': 307, 'max_depth': 22, 'min_samples_leaf': 28, 'min_samples_split': 11, 'class_weight_option': 'balanced_subsample'}. Best is trial 46 with value: 0.6359251851323043.
# [I 2025-11-22 01:09:24,515] Trial 47 finished with value: 0.6353980906080733 and parameters: {'n_estimators': 301, 'max_depth': 21, 'min_samples_leaf': 27, 'min_samples_split': 11, 'class_weight_option': 'balanced_subsample'}. Best is trial 46 with value: 0.6359251851323043.
# [I 2025-11-22 01:09:31,134] Trial 48 finished with value: 0.6357313196338709 and parameters: {'n_estimators': 253, 'max_depth': 21, 'min_samples_leaf': 28, 'min_samples_split': 11, 'class_weight_option': 'balanced_subsample'}. Best is trial 46 with value: 0.6359251851323043.
# [I 2025-11-22 01:09:35,137] Trial 49 finished with value: 0.630154523006347 and parameters: {'n_estimators': 164, 'max_depth': 20, 'min_samples_leaf': 42, 'min_samples_split': 6, 'class_weight_option': 'balanced_subsample'}. Best is trial 46 with value: 0.6359251851323043.

# %%
print("Best trial:")
trial = RF_study.best_trial
print("  F1: {:.4f}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   F1: 0.6359
#   Params:
#     n_estimators: 307
#     max_depth: 22
#     min_samples_leaf: 28
#     min_samples_split: 11
#     class_weight_option: balanced_subsample

# %%
mlflow.set_experiment("Customer_Churn")

scoring = ['roc_auc', 'f1', 'precision', 'recall']

RF_clf = RandomForestClassifier(n_estimators=307, max_depth=22, min_samples_leaf=28, min_samples_split=11, class_weight='balanced_subsample')

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name='RandomForest'):
    mlflow.log_param("model", "RadomForest")
    mlflow.log_param("class_weight", "balanced_subsample")
    mlflow.log_param("max_depth", 307)
    mlflow.log_param("min_samples_leaf", 28)
    mlflow.log_param("min_samples_split", 11)
    
    scores = cross_validate(RF_clf, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    RF_clf.fit(X, y)
    mlflow.sklearn.log_model(RF_clf, "RandomForest")

pd.DataFrame(scores)
# Out:
# roc_auc: mean=0.846
# f1: mean=0.634
# precision: mean=0.528
# recall: mean=0.796
# 2025/11/22 01:23:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/22 01:24:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  1.903985    0.106137      0.858489  0.648765        0.542190     0.807487
# 1  1.559465    0.095682      0.844105  0.632231        0.515152     0.818182
# 2  1.520422    0.092243      0.856079  0.646617        0.540395     0.804813
# 3  1.523029    0.097767      0.828957  0.613537        0.517495     0.753351
# 4  1.491919    0.101302      0.842330  0.631243        0.523810     0.794118

# %% [markdown]
# # GradientBoosting

# %% [markdown]
# ## LightGBM

# %%
def objective_lightGBM(trial):

    params = {
        'n_estimators': trial.suggest_int('n_estimators', 50, 1000), 
        'max_depth': trial.suggest_int('max_depth', 4, 12),           
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),  
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 1.0),         
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 1.0),
        'min_child_samples': trial.suggest_int('min_child_samples', 5, 30),    
        'random_state': 42,
        'n_jobs': -1,
        'class_weight': trial.suggest_categorical('class_weight',[None, 'balanced']),
        'verbose': -1
    }

    LGBM_clf = LGBMClassifier(**params)

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(LGBM_clf, X, y, cv=skf, scoring='f1')

    return scores.mean()

# %%
LGBM_study = optuna.create_study(direction='maximize')  
LGBM_study.optimize(objective_lightGBM, n_trials=50)
# Out:
# [I 2025-11-22 01:59:29,226] A new study created in memory with name: no-name-0de42b41-b693-433a-b0e5-82a31bc11a7e
# [I 2025-11-22 01:59:30,565] Trial 0 finished with value: 0.6311512231962821 and parameters: {'n_estimators': 580, 'max_depth': 4, 'learning_rate': 0.016057278395072698, 'reg_alpha': 0.4156145065777953, 'reg_lambda': 0.7626639332961559, 'min_child_samples': 21, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:33,196] Trial 1 finished with value: 0.578788877163454 and parameters: {'n_estimators': 945, 'max_depth': 5, 'learning_rate': 0.013467714084683606, 'reg_alpha': 0.7315104796238954, 'reg_lambda': 0.31681890533174417, 'min_child_samples': 23, 'class_weight': None}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:34,555] Trial 2 finished with value: 0.5742154310001315 and parameters: {'n_estimators': 651, 'max_depth': 4, 'learning_rate': 0.039174334533794736, 'reg_alpha': 0.3014065119213568, 'reg_lambda': 0.09711462952601159, 'min_child_samples': 13, 'class_weight': None}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:37,199] Trial 3 finished with value: 0.5743111209302877 and parameters: {'n_estimators': 860, 'max_depth': 5, 'learning_rate': 0.04788646794147809, 'reg_alpha': 0.7492609261395085, 'reg_lambda': 0.48144262401563137, 'min_child_samples': 8, 'class_weight': None}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:40,705] Trial 4 finished with value: 0.5699088241564649 and parameters: {'n_estimators': 408, 'max_depth': 8, 'learning_rate': 0.061538951483414185, 'reg_alpha': 0.12416038816257509, 'reg_lambda': 0.6996982764240927, 'min_child_samples': 18, 'class_weight': None}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:42,618] Trial 5 finished with value: 0.5704135266424233 and parameters: {'n_estimators': 357, 'max_depth': 6, 'learning_rate': 0.03266396526850237, 'reg_alpha': 0.11001780054759278, 'reg_lambda': 0.9795092659451066, 'min_child_samples': 16, 'class_weight': None}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:44,123] Trial 6 finished with value: 0.6087471711723775 and parameters: {'n_estimators': 598, 'max_depth': 4, 'learning_rate': 0.06917924671614661, 'reg_alpha': 0.08120247127410594, 'reg_lambda': 0.4503903685811519, 'min_child_samples': 27, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:45,328] Trial 7 finished with value: 0.6109892744066544 and parameters: {'n_estimators': 254, 'max_depth': 12, 'learning_rate': 0.06614903130625678, 'reg_alpha': 0.3259667287474186, 'reg_lambda': 0.2737590938570821, 'min_child_samples': 13, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:47,898] Trial 8 finished with value: 0.5951252486814083 and parameters: {'n_estimators': 601, 'max_depth': 12, 'learning_rate': 0.08882436419600502, 'reg_alpha': 0.21857171578426307, 'reg_lambda': 0.3087631620019855, 'min_child_samples': 19, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:49,037] Trial 9 finished with value: 0.6087309694560199 and parameters: {'n_estimators': 245, 'max_depth': 12, 'learning_rate': 0.08265140903154895, 'reg_alpha': 0.38892206316339634, 'reg_lambda': 0.08260145399376692, 'min_child_samples': 26, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:49,456] Trial 10 finished with value: 0.6284812182134983 and parameters: {'n_estimators': 52, 'max_depth': 8, 'learning_rate': 0.010131276754528358, 'reg_alpha': 0.9786242527185239, 'reg_lambda': 0.7759985549389623, 'min_child_samples': 7, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:50,318] Trial 11 finished with value: 0.6295730709175325 and parameters: {'n_estimators': 147, 'max_depth': 9, 'learning_rate': 0.01048479709045954, 'reg_alpha': 0.9095301034763511, 'reg_lambda': 0.7653522819777983, 'min_child_samples': 5, 'class_weight': 'balanced'}. Best is trial 0 with value: 0.6311512231962821.
# [I 2025-11-22 01:59:50,764] Trial 12 finished with value: 0.6329918493346046 and parameters: {'n_estimators': 57, 'max_depth': 10, 'learning_rate': 0.025268284223724718, 'reg_alpha': 0.5678758703256552, 'reg_lambda': 0.7787969545227066, 'min_child_samples': 22, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 01:59:54,240] Trial 13 finished with value: 0.6146780256255224 and parameters: {'n_estimators': 738, 'max_depth': 10, 'learning_rate': 0.026760259180696005, 'reg_alpha': 0.5178425065283901, 'reg_lambda': 0.9570185418293419, 'min_child_samples': 23, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 01:59:56,487] Trial 14 finished with value: 0.6211157557124932 and parameters: {'n_estimators': 428, 'max_depth': 10, 'learning_rate': 0.02444394703034547, 'reg_alpha': 0.5225571576070687, 'reg_lambda': 0.6266767463468541, 'min_child_samples': 22, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 01:59:59,884] Trial 15 finished with value: 0.6006551693108775 and parameters: {'n_estimators': 761, 'max_depth': 7, 'learning_rate': 0.04503031535812491, 'reg_alpha': 0.64564629477939, 'reg_lambda': 0.8466914714732088, 'min_child_samples': 20, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:02,318] Trial 16 finished with value: 0.6140418525632831 and parameters: {'n_estimators': 515, 'max_depth': 10, 'learning_rate': 0.021622660685485972, 'reg_alpha': 0.42864860723799286, 'reg_lambda': 0.5844401663923076, 'min_child_samples': 30, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:04,552] Trial 17 finished with value: 0.6142227463248865 and parameters: {'n_estimators': 491, 'max_depth': 7, 'learning_rate': 0.03493854074263206, 'reg_alpha': 0.6199127731530327, 'reg_lambda': 0.8718562351292114, 'min_child_samples': 15, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:06,133] Trial 18 finished with value: 0.6288637809498863 and parameters: {'n_estimators': 299, 'max_depth': 11, 'learning_rate': 0.023370816255404884, 'reg_alpha': 0.8258361244468757, 'reg_lambda': 0.6148553972492574, 'min_child_samples': 26, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:06,844] Trial 19 finished with value: 0.6270891795504943 and parameters: {'n_estimators': 140, 'max_depth': 9, 'learning_rate': 0.05199645975307138, 'reg_alpha': 0.6441627538030347, 'reg_lambda': 0.7083584620371945, 'min_child_samples': 30, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:10,075] Trial 20 finished with value: 0.6122121522554033 and parameters: {'n_estimators': 790, 'max_depth': 6, 'learning_rate': 0.019205188174453398, 'reg_alpha': 0.4598468052861874, 'reg_lambda': 0.8742711886740048, 'min_child_samples': 21, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:10,880] Trial 21 finished with value: 0.6299696433450999 and parameters: {'n_estimators': 132, 'max_depth': 9, 'learning_rate': 0.011252183384818286, 'reg_alpha': 0.8022203181636687, 'reg_lambda': 0.7550068113616866, 'min_child_samples': 5, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:11,336] Trial 22 finished with value: 0.631758986975948 and parameters: {'n_estimators': 59, 'max_depth': 9, 'learning_rate': 0.031028848127281884, 'reg_alpha': 0.56172647349233, 'reg_lambda': 0.7938627664519778, 'min_child_samples': 10, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:11,956] Trial 23 finished with value: 0.6297744852647618 and parameters: {'n_estimators': 81, 'max_depth': 11, 'learning_rate': 0.03052172413934292, 'reg_alpha': 0.5694330776624534, 'reg_lambda': 0.5470437331196726, 'min_child_samples': 10, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:13,404] Trial 24 finished with value: 0.6243494271579866 and parameters: {'n_estimators': 221, 'max_depth': 8, 'learning_rate': 0.03991168470863742, 'reg_alpha': 0.3341543883335304, 'reg_lambda': 0.9007219270850184, 'min_child_samples': 16, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:15,771] Trial 25 finished with value: 0.6284989707156853 and parameters: {'n_estimators': 352, 'max_depth': 11, 'learning_rate': 0.017585716454937186, 'reg_alpha': 0.21309761475756112, 'reg_lambda': 0.6783380432062417, 'min_child_samples': 11, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:16,855] Trial 26 finished with value: 0.5701640056959272 and parameters: {'n_estimators': 191, 'max_depth': 9, 'learning_rate': 0.029847034648055756, 'reg_alpha': 0.5922409721076727, 'reg_lambda': 0.40444453135479946, 'min_child_samples': 24, 'class_weight': None}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:21,477] Trial 27 finished with value: 0.6063029854957106 and parameters: {'n_estimators': 660, 'max_depth': 7, 'learning_rate': 0.04093511720681528, 'reg_alpha': 0.7074815368766816, 'reg_lambda': 0.810584487584434, 'min_child_samples': 19, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:22,287] Trial 28 finished with value: 0.6294471559766198 and parameters: {'n_estimators': 82, 'max_depth': 10, 'learning_rate': 0.017441871258139605, 'reg_alpha': 0.47138388912288587, 'reg_lambda': 0.9311086503940094, 'min_child_samples': 14, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:26,210] Trial 29 finished with value: 0.5624188335835071 and parameters: {'n_estimators': 991, 'max_depth': 5, 'learning_rate': 0.054960937415429054, 'reg_alpha': 0.38837966942623153, 'reg_lambda': 0.6804867806924569, 'min_child_samples': 17, 'class_weight': None}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:27,784] Trial 30 finished with value: 0.618451606557539 and parameters: {'n_estimators': 337, 'max_depth': 6, 'learning_rate': 0.03547009153842522, 'reg_alpha': 0.6841372177404573, 'reg_lambda': 0.9912688297050449, 'min_child_samples': 25, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:28,719] Trial 31 finished with value: 0.6314089450647156 and parameters: {'n_estimators': 142, 'max_depth': 9, 'learning_rate': 0.014740043942953637, 'reg_alpha': 0.801406311126185, 'reg_lambda': 0.7631061950047651, 'min_child_samples': 5, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:29,802] Trial 32 finished with value: 0.630861962856506 and parameters: {'n_estimators': 168, 'max_depth': 8, 'learning_rate': 0.015527724177738761, 'reg_alpha': 0.8545728526259477, 'reg_lambda': 0.8126444837634385, 'min_child_samples': 10, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:30,304] Trial 33 finished with value: 0.6278587488743441 and parameters: {'n_estimators': 68, 'max_depth': 9, 'learning_rate': 0.025274689235215822, 'reg_alpha': 0.5370863359748117, 'reg_lambda': 0.5351589907652256, 'min_child_samples': 8, 'class_weight': 'balanced'}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:30,686] Trial 34 finished with value: 0.5133844906657858 and parameters: {'n_estimators': 110, 'max_depth': 4, 'learning_rate': 0.01623702449367756, 'reg_alpha': 0.7606800353248101, 'reg_lambda': 0.1978240465597031, 'min_child_samples': 6, 'class_weight': None}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:32,161] Trial 35 finished with value: 0.5726562317342718 and parameters: {'n_estimators': 283, 'max_depth': 10, 'learning_rate': 0.04618368385656347, 'reg_alpha': 0.251152955313974, 'reg_lambda': 0.7359537597307957, 'min_child_samples': 9, 'class_weight': None}. Best is trial 12 with value: 0.6329918493346046.
# [I 2025-11-22 02:00:33,418] Trial 36 finished with value: 0.6335847592331043 and parameters: {'n_estimators': 204, 'max_depth': 8, 'learning_rate': 0.027066195939323433, 'reg_alpha': 0.9102322286077551, 'reg_lambda': 0.649098245716251, 'min_child_samples': 12, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:34,594] Trial 37 finished with value: 0.6283546571752469 and parameters: {'n_estimators': 189, 'max_depth': 9, 'learning_rate': 0.030560969342489114, 'reg_alpha': 0.9696552913981606, 'reg_lambda': 0.8183597409663917, 'min_child_samples': 12, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:35,829] Trial 38 finished with value: 0.6270417616767376 and parameters: {'n_estimators': 216, 'max_depth': 8, 'learning_rate': 0.03660701430891665, 'reg_alpha': 0.8868542114134701, 'reg_lambda': 0.6803655737826115, 'min_child_samples': 8, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:36,577] Trial 39 finished with value: 0.6308578341227773 and parameters: {'n_estimators': 114, 'max_depth': 11, 'learning_rate': 0.027673465720263704, 'reg_alpha': 0.8053563392284719, 'reg_lambda': 0.6314019086265401, 'min_child_samples': 12, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:38,647] Trial 40 finished with value: 0.5632516952879174 and parameters: {'n_estimators': 412, 'max_depth': 8, 'learning_rate': 0.07510503581020156, 'reg_alpha': 0.01635746019827683, 'reg_lambda': 0.46741805287238053, 'min_child_samples': 14, 'class_weight': None}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:40,999] Trial 41 finished with value: 0.6233258784678319 and parameters: {'n_estimators': 575, 'max_depth': 5, 'learning_rate': 0.02105438689903657, 'reg_alpha': 0.930467007489813, 'reg_lambda': 0.7363542675932943, 'min_child_samples': 18, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:43,232] Trial 42 finished with value: 0.6011289837611054 and parameters: {'n_estimators': 469, 'max_depth': 7, 'learning_rate': 0.09696225236906111, 'reg_alpha': 0.773590391409825, 'reg_lambda': 0.7858500179481513, 'min_child_samples': 22, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:46,795] Trial 43 finished with value: 0.6258958459316585 and parameters: {'n_estimators': 659, 'max_depth': 10, 'learning_rate': 0.013350897356634521, 'reg_alpha': 0.7050761116515342, 'reg_lambda': 0.9260541543442307, 'min_child_samples': 20, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:48,360] Trial 44 finished with value: 0.6082802315222899 and parameters: {'n_estimators': 555, 'max_depth': 4, 'learning_rate': 0.06132124918676446, 'reg_alpha': 0.41077260591318343, 'reg_lambda': 0.40948694438453, 'min_child_samples': 7, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:49,711] Trial 45 finished with value: 0.6297917414593429 and parameters: {'n_estimators': 260, 'max_depth': 6, 'learning_rate': 0.020091946217567085, 'reg_alpha': 0.36513610821337217, 'reg_lambda': 0.8538935010410764, 'min_child_samples': 23, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:50,180] Trial 46 finished with value: 0.62842752733354 and parameters: {'n_estimators': 60, 'max_depth': 9, 'learning_rate': 0.024084468950557596, 'reg_alpha': 0.2866776857538047, 'reg_lambda': 0.6444770099965249, 'min_child_samples': 6, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:51,147] Trial 47 finished with value: 0.6216216497396807 and parameters: {'n_estimators': 169, 'max_depth': 10, 'learning_rate': 0.04229424846143705, 'reg_alpha': 0.47527139001063823, 'reg_lambda': 0.7286717305543877, 'min_child_samples': 28, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:00:54,277] Trial 48 finished with value: 0.6102851169371559 and parameters: {'n_estimators': 622, 'max_depth': 12, 'learning_rate': 0.03389397225583431, 'reg_alpha': 0.5727105414422555, 'reg_lambda': 0.5612036118452081, 'min_child_samples': 17, 'class_weight': 'balanced'}. Best is trial 36 with value: 0.6335847592331043.
# [I 2025-11-22 02:01:00,151] Trial 49 finished with value: 0.5774862416865036 and parameters: {'n_estimators': 876, 'max_depth': 11, 'learning_rate': 0.01326351043242241, 'reg_alpha': 0.9561342777968785, 'reg_lambda': 0.7821532438721107, 'min_child_samples': 21, 'class_weight': None}. Best is trial 36 with value: 0.6335847592331043.

# %%
print("Best trial:")
trial = LGBM_study .best_trial
print("  F1: {:.4f}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   F1: 0.6326
#   Params:
#     n_estimators: 111
#     max_depth: 10
#     learning_rate: 0.04644400497008506
#     reg_alpha: 0.26686424971094025
#     reg_lambda: 0.4747510539958262
#     min_child_samples: 18
#     class_weight: balanced

# %%
mlflow.set_experiment("Customer_Churn")
params = {
        'n_estimators': 111, 
        'max_depth': 10,
        'learning_rate': 0.05,  
        'reg_alpha': 0.26,
        'reg_lambda': 0.47,
        'min_child_samples': 18,    
        'random_state': 42,
        'n_jobs': -1,
        'class_weight':'balanced',
        'verbose': -1
    }


scoring = ['roc_auc', 'f1', 'precision', 'recall']

LGBM_clf = LGBMClassifier(**params)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name='LGBM'):
    mlflow.log_param("model", "LGBM")
    for param, value in params.items():
        mlflow.log_param(param, value)
   
    
    scores = cross_validate(LGBM_clf, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    LGBM_clf.fit(X, y)
    mlflow.lightgbm.log_model(LGBM_clf, "LGBM")

pd.DataFrame(scores)
# Out:
# 2025/11/22 02:33:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# roc_auc: mean=0.842
# f1: mean=0.630
# precision: mean=0.535
# recall: mean=0.766
# 2025/11/22 02:33:38 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  0.108547    0.021525      0.852873  0.644105        0.544280     0.788770
# 1  0.097876    0.021526      0.841751  0.615721        0.520295     0.754011
# 2  0.088726    0.020811      0.845997  0.647256        0.556840     0.772727
# 3  0.207994    0.021247      0.830379  0.625821        0.528651     0.766756
# 4  0.116232    0.017022      0.838123  0.616740        0.524345     0.748663

# %% [markdown]
# ## XGboost

# %%
def objective_xgboost(trial):

    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 1000),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3, log=True),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0, log=True),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 1e-8, 1.0, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-8, 1.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-8, 1.0, log=True),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        "eval_metric": "logloss",
        "random_state": 42,
        "n_jobs": -1,
        "tree_method": "hist"  
    }

    model = XGBClassifier(**params)

    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X, y, cv=skf, scoring="f1")

    return scores.mean()

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective_xgboost, n_trials=50)

print("Лучшие параметры:", study.best_params)
print("Лучший F1:", study.best_value)
# Out:
# [I 2025-11-22 02:38:57,046] A new study created in memory with name: no-name-77322e32-401a-40c2-86ac-8c42f57efb2f
# [I 2025-11-22 02:39:00,777] Trial 0 finished with value: 0.5537670298554621 and parameters: {'n_estimators': 431, 'max_depth': 12, 'learning_rate': 0.04854616944919315, 'subsample': 0.5787268708839483, 'colsample_bytree': 0.825635961308615, 'gamma': 3.081650493273894e-05, 'reg_alpha': 1.4616074492966517e-05, 'reg_lambda': 1.3844274386279643e-05, 'min_child_weight': 2}. Best is trial 0 with value: 0.5537670298554621.
# [I 2025-11-22 02:39:07,681] Trial 1 finished with value: 0.5526415070794546 and parameters: {'n_estimators': 890, 'max_depth': 10, 'learning_rate': 0.02510625295026713, 'subsample': 0.7552303264539141, 'colsample_bytree': 0.6432121230201598, 'gamma': 0.0040969284622755205, 'reg_alpha': 0.000266375346037615, 'reg_lambda': 0.0009871074916171865, 'min_child_weight': 1}. Best is trial 0 with value: 0.5537670298554621.
# [I 2025-11-22 02:39:09,650] Trial 2 finished with value: 0.5635531436567973 and parameters: {'n_estimators': 415, 'max_depth': 10, 'learning_rate': 0.08571883577625723, 'subsample': 0.5672390051675438, 'colsample_bytree': 0.8585825230793269, 'gamma': 4.690556620777367e-08, 'reg_alpha': 1.48970248591232e-06, 'reg_lambda': 4.0061758756107155e-06, 'min_child_weight': 13}. Best is trial 2 with value: 0.5635531436567973.
# [I 2025-11-22 02:39:13,774] Trial 3 finished with value: 0.5655482004889638 and parameters: {'n_estimators': 798, 'max_depth': 10, 'learning_rate': 0.04015315897814591, 'subsample': 0.7985371971355743, 'colsample_bytree': 0.6014272659247946, 'gamma': 0.004407716611802363, 'reg_alpha': 0.002036342275504446, 'reg_lambda': 0.02447982664667047, 'min_child_weight': 15}. Best is trial 3 with value: 0.5655482004889638.
# [I 2025-11-22 02:39:17,499] Trial 4 finished with value: 0.5686711298049619 and parameters: {'n_estimators': 705, 'max_depth': 9, 'learning_rate': 0.06325475852903382, 'subsample': 0.7413234469077761, 'colsample_bytree': 0.8213361461284632, 'gamma': 1.0817533144596515e-05, 'reg_alpha': 0.009825896352044512, 'reg_lambda': 0.0067412360801123415, 'min_child_weight': 19}. Best is trial 4 with value: 0.5686711298049619.
# [I 2025-11-22 02:39:20,569] Trial 5 finished with value: 0.5546732973122559 and parameters: {'n_estimators': 724, 'max_depth': 3, 'learning_rate': 0.20040944115681106, 'subsample': 0.6863846850274873, 'colsample_bytree': 0.7094472623545376, 'gamma': 0.003447164159604158, 'reg_alpha': 0.15134193616323155, 'reg_lambda': 9.908361508703741e-08, 'min_child_weight': 6}. Best is trial 4 with value: 0.5686711298049619.
# [I 2025-11-22 02:39:24,273] Trial 6 finished with value: 0.5602603262856349 and parameters: {'n_estimators': 442, 'max_depth': 7, 'learning_rate': 0.2003156417905278, 'subsample': 0.5041577499701292, 'colsample_bytree': 0.7433276435498473, 'gamma': 5.728466389485418e-08, 'reg_alpha': 6.80496047269644e-05, 'reg_lambda': 0.0028551089787530225, 'min_child_weight': 15}. Best is trial 4 with value: 0.5686711298049619.
# [I 2025-11-22 02:39:30,909] Trial 7 finished with value: 0.5816031686636907 and parameters: {'n_estimators': 916, 'max_depth': 4, 'learning_rate': 0.04810340101237857, 'subsample': 0.9178559231768765, 'colsample_bytree': 0.7927588204799085, 'gamma': 0.5920726223317448, 'reg_alpha': 0.010892492062741769, 'reg_lambda': 1.2321489116724437e-06, 'min_child_weight': 16}. Best is trial 7 with value: 0.5816031686636907.
# [I 2025-11-22 02:39:36,067] Trial 8 finished with value: 0.562793256573886 and parameters: {'n_estimators': 810, 'max_depth': 4, 'learning_rate': 0.11896207438846293, 'subsample': 0.7279781048952407, 'colsample_bytree': 0.7126719720474978, 'gamma': 8.79866814324787e-06, 'reg_alpha': 0.0039284732744333415, 'reg_lambda': 0.9591955080837853, 'min_child_weight': 19}. Best is trial 7 with value: 0.5816031686636907.
# [I 2025-11-22 02:39:39,351] Trial 9 finished with value: 0.5872704837246693 and parameters: {'n_estimators': 675, 'max_depth': 3, 'learning_rate': 0.018124680982564367, 'subsample': 0.713959579175174, 'colsample_bytree': 0.5397376390204913, 'gamma': 0.003423245379642707, 'reg_alpha': 7.314780653228606e-06, 'reg_lambda': 0.00044717815835973457, 'min_child_weight': 6}. Best is trial 9 with value: 0.5872704837246693.
# [I 2025-11-22 02:39:41,424] Trial 10 finished with value: 0.5683623633494742 and parameters: {'n_estimators': 261, 'max_depth': 6, 'learning_rate': 0.010242277116266478, 'subsample': 0.9299925496013569, 'colsample_bytree': 0.5342601799510203, 'gamma': 0.2764581425570246, 'reg_alpha': 1.9876232722035693e-08, 'reg_lambda': 1.4297771575462116e-08, 'min_child_weight': 8}. Best is trial 9 with value: 0.5872704837246693.
# [I 2025-11-22 02:39:45,468] Trial 11 finished with value: 0.5835086407190752 and parameters: {'n_estimators': 996, 'max_depth': 5, 'learning_rate': 0.016890108791920395, 'subsample': 0.9600550505457639, 'colsample_bytree': 0.9772715732019956, 'gamma': 0.6586008564758192, 'reg_alpha': 7.985962062364354e-07, 'reg_lambda': 2.9359411881806802e-06, 'min_child_weight': 9}. Best is trial 9 with value: 0.5872704837246693.
# [I 2025-11-22 02:39:49,732] Trial 12 finished with value: 0.5830408552931893 and parameters: {'n_estimators': 985, 'max_depth': 5, 'learning_rate': 0.014335327372086867, 'subsample': 0.9882306330196622, 'colsample_bytree': 0.9921724504209233, 'gamma': 0.07587388179254266, 'reg_alpha': 4.161492433180422e-07, 'reg_lambda': 0.0001085301267726865, 'min_child_weight': 9}. Best is trial 9 with value: 0.5872704837246693.
# [I 2025-11-22 02:39:51,824] Trial 13 finished with value: 0.5881595531040392 and parameters: {'n_estimators': 576, 'max_depth': 3, 'learning_rate': 0.022559128729061455, 'subsample': 0.8363385190195524, 'colsample_bytree': 0.9991977735378887, 'gamma': 0.04442918192518685, 'reg_alpha': 5.55480342329735e-07, 'reg_lambda': 9.013987786227757e-05, 'min_child_weight': 5}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:39:54,021] Trial 14 finished with value: 0.5825546773350847 and parameters: {'n_estimators': 590, 'max_depth': 3, 'learning_rate': 0.024298871589188958, 'subsample': 0.8238716242728529, 'colsample_bytree': 0.5114707083586238, 'gamma': 0.00039515798107799796, 'reg_alpha': 2.9479386488294333e-08, 'reg_lambda': 0.0001394245741363323, 'min_child_weight': 5}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:39:57,627] Trial 15 finished with value: 0.570204819314433 and parameters: {'n_estimators': 580, 'max_depth': 7, 'learning_rate': 0.0253192865970181, 'subsample': 0.651912226772693, 'colsample_bytree': 0.9410883207229166, 'gamma': 0.03209438974633504, 'reg_alpha': 7.188496930894841e-06, 'reg_lambda': 0.13955298979399322, 'min_child_weight': 4}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:39:59,694] Trial 16 finished with value: 0.5853253606127599 and parameters: {'n_estimators': 519, 'max_depth': 3, 'learning_rate': 0.010746115386629005, 'subsample': 0.8522807297618684, 'colsample_bytree': 0.9006093810249653, 'gamma': 1.1248284506957568e-06, 'reg_alpha': 8.153232011628234e-08, 'reg_lambda': 0.0004177305669732833, 'min_child_weight': 12}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:02,927] Trial 17 finished with value: 0.5696670661148925 and parameters: {'n_estimators': 688, 'max_depth': 5, 'learning_rate': 0.03203025764955653, 'subsample': 0.6431583117698911, 'colsample_bytree': 0.6283639800373712, 'gamma': 0.00020033695692575325, 'reg_alpha': 1.2751204442123841e-05, 'reg_lambda': 4.1763270037325366e-05, 'min_child_weight': 6}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:05,153] Trial 18 finished with value: 0.5713917158506698 and parameters: {'n_estimators': 290, 'max_depth': 8, 'learning_rate': 0.016889142745516474, 'subsample': 0.8682926610531149, 'colsample_bytree': 0.5699731957581519, 'gamma': 0.02487380209993058, 'reg_alpha': 1.7579211620531858e-07, 'reg_lambda': 2.9395913961595825e-07, 'min_child_weight': 3}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:07,195] Trial 19 finished with value: 0.5849086395431158 and parameters: {'n_estimators': 519, 'max_depth': 4, 'learning_rate': 0.019735842652302535, 'subsample': 0.778962605905412, 'colsample_bytree': 0.6895152276419754, 'gamma': 0.0007082812461755891, 'reg_alpha': 0.00018447785200716832, 'reg_lambda': 2.0801992376687837e-05, 'min_child_weight': 7}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:10,545] Trial 20 finished with value: 0.5721106369812302 and parameters: {'n_estimators': 653, 'max_depth': 6, 'learning_rate': 0.03159168731194968, 'subsample': 0.6902357305493358, 'colsample_bytree': 0.9007477129174284, 'gamma': 0.001380705626774562, 'reg_alpha': 3.8010644292599827e-06, 'reg_lambda': 0.007652583132767733, 'min_child_weight': 10}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:12,520] Trial 21 finished with value: 0.5855306359415039 and parameters: {'n_estimators': 501, 'max_depth': 3, 'learning_rate': 0.011103304356033333, 'subsample': 0.8562441169989353, 'colsample_bytree': 0.9219207854350446, 'gamma': 6.204994638158434e-07, 'reg_alpha': 6.199038971800392e-08, 'reg_lambda': 0.0008475943693992338, 'min_child_weight': 12}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:13,952] Trial 22 finished with value: 0.5815182009934793 and parameters: {'n_estimators': 359, 'max_depth': 3, 'learning_rate': 0.01298976376316075, 'subsample': 0.8729473089864983, 'colsample_bytree': 0.9395734355889944, 'gamma': 7.894728280964325e-07, 'reg_alpha': 1.3038719830357808e-08, 'reg_lambda': 0.0007299956880409282, 'min_child_weight': 11}. Best is trial 13 with value: 0.5881595531040392.
# [I 2025-11-22 02:40:16,078] Trial 23 finished with value: 0.5901435039984579 and parameters: {'n_estimators': 506, 'max_depth': 4, 'learning_rate': 0.013341911337083321, 'subsample': 0.8170550508278221, 'colsample_bytree': 0.9966545466391288, 'gamma': 0.01427356433243341, 'reg_alpha': 1.486065496550717e-07, 'reg_lambda': 0.04548629225378468, 'min_child_weight': 4}. Best is trial 23 with value: 0.5901435039984579.
# [I 2025-11-22 02:40:18,507] Trial 24 finished with value: 0.5852635765097145 and parameters: {'n_estimators': 601, 'max_depth': 4, 'learning_rate': 0.018609225059954215, 'subsample': 0.8031233570137174, 'colsample_bytree': 0.98661492558053, 'gamma': 0.014729828107215378, 'reg_alpha': 3.2908022012524164e-07, 'reg_lambda': 0.040513297264354195, 'min_child_weight': 4}. Best is trial 23 with value: 0.5901435039984579.
# [I 2025-11-22 02:40:22,957] Trial 25 finished with value: 0.5619174517757471 and parameters: {'n_estimators': 755, 'max_depth': 6, 'learning_rate': 0.03525074269645519, 'subsample': 0.6391998061909087, 'colsample_bytree': 0.8801001882164455, 'gamma': 0.12243677031181494, 'reg_alpha': 1.6274573428176686e-06, 'reg_lambda': 0.09248314741897776, 'min_child_weight': 1}. Best is trial 23 with value: 0.5901435039984579.
# [I 2025-11-22 02:40:26,427] Trial 26 finished with value: 0.5790129486375687 and parameters: {'n_estimators': 648, 'max_depth': 5, 'learning_rate': 0.021555123167866657, 'subsample': 0.7595676847164108, 'colsample_bytree': 0.9564070231529911, 'gamma': 0.010937778488819291, 'reg_alpha': 4.3808291188141136e-05, 'reg_lambda': 0.000127994102129922, 'min_child_weight': 3}. Best is trial 23 with value: 0.5901435039984579.
# [I 2025-11-22 02:40:28,614] Trial 27 finished with value: 0.5905333910082331 and parameters: {'n_estimators': 557, 'max_depth': 4, 'learning_rate': 0.014248074439395327, 'subsample': 0.6965177940657781, 'colsample_bytree': 0.8477507656565151, 'gamma': 0.08716186049380047, 'reg_alpha': 2.985738729785991e-06, 'reg_lambda': 0.0044089064287612615, 'min_child_weight': 7}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:30,110] Trial 28 finished with value: 0.5835254230531087 and parameters: {'n_estimators': 340, 'max_depth': 4, 'learning_rate': 0.01361848206616942, 'subsample': 0.5930149110277524, 'colsample_bytree': 0.8496543398500435, 'gamma': 0.10753068681350683, 'reg_alpha': 1.242552592752744e-07, 'reg_lambda': 0.4151775210975113, 'min_child_weight': 8}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:32,690] Trial 29 finished with value: 0.5613459735888255 and parameters: {'n_estimators': 466, 'max_depth': 6, 'learning_rate': 0.06547528246649595, 'subsample': 0.823266473442531, 'colsample_bytree': 0.7932112524790546, 'gamma': 3.506477892034934e-05, 'reg_alpha': 3.011594899864922e-06, 'reg_lambda': 0.004454185420408655, 'min_child_weight': 3}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:36,180] Trial 30 finished with value: 0.5697181639594548 and parameters: {'n_estimators': 390, 'max_depth': 11, 'learning_rate': 0.014779896391482653, 'subsample': 0.9127640397522062, 'colsample_bytree': 0.8135448110201224, 'gamma': 0.06695584945687093, 'reg_alpha': 7.132620034686788e-07, 'reg_lambda': 0.02035778716672795, 'min_child_weight': 5}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:38,448] Trial 31 finished with value: 0.5802315632935515 and parameters: {'n_estimators': 560, 'max_depth': 4, 'learning_rate': 0.027529936490214346, 'subsample': 0.7069050963848208, 'colsample_bytree': 0.7637172256482977, 'gamma': 0.009757097613814325, 'reg_alpha': 3.195936908386711e-05, 'reg_lambda': 0.002588727588853178, 'min_child_weight': 7}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:40,709] Trial 32 finished with value: 0.5869549637111672 and parameters: {'n_estimators': 639, 'max_depth': 3, 'learning_rate': 0.019825784834912496, 'subsample': 0.6018288574909442, 'colsample_bytree': 0.9999322292672728, 'gamma': 0.0017719565123931716, 'reg_alpha': 1.82014028804664e-05, 'reg_lambda': 2.5912896024833837e-05, 'min_child_weight': 5}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:47,242] Trial 33 finished with value: 0.5691186118532332 and parameters: {'n_estimators': 554, 'max_depth': 12, 'learning_rate': 0.01203797316468657, 'subsample': 0.7303921948637554, 'colsample_bytree': 0.6626296118993408, 'gamma': 0.28713692789627904, 'reg_alpha': 0.0005234211813916527, 'reg_lambda': 0.0002675803992293869, 'min_child_weight': 1}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:48,286] Trial 34 finished with value: 0.5808772547441876 and parameters: {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.01622232751476388, 'subsample': 0.6642562678749702, 'colsample_bytree': 0.864533641373487, 'gamma': 0.0046121815787875725, 'reg_alpha': 6.498698217699982e-06, 'reg_lambda': 0.001821347073429144, 'min_child_weight': 7}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:50,154] Trial 35 finished with value: 0.5736540959447123 and parameters: {'n_estimators': 502, 'max_depth': 4, 'learning_rate': 0.04233939678809948, 'subsample': 0.7686894253458955, 'colsample_bytree': 0.9592323269208889, 'gamma': 0.03761791236011454, 'reg_alpha': 1.255975810493003e-06, 'reg_lambda': 0.018324952879665686, 'min_child_weight': 2}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:52,957] Trial 36 finished with value: 0.590292549614414 and parameters: {'n_estimators': 779, 'max_depth': 3, 'learning_rate': 0.022718821773813618, 'subsample': 0.5525583303542856, 'colsample_bytree': 0.9098657198838821, 'gamma': 6.341113050410094e-05, 'reg_alpha': 2.189871928049491e-07, 'reg_lambda': 1.0042732392942196e-05, 'min_child_weight': 6}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:40:58,112] Trial 37 finished with value: 0.5441030054554072 and parameters: {'n_estimators': 827, 'max_depth': 9, 'learning_rate': 0.10107060025804997, 'subsample': 0.5279804672620505, 'colsample_bytree': 0.9155257037712847, 'gamma': 7.752100822690918e-05, 'reg_alpha': 2.881757484025697e-07, 'reg_lambda': 1.737592095166596e-06, 'min_child_weight': 4}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:00,871] Trial 38 finished with value: 0.5870088914258703 and parameters: {'n_estimators': 873, 'max_depth': 3, 'learning_rate': 0.022878737571537397, 'subsample': 0.5480894341635877, 'colsample_bytree': 0.8477603874939307, 'gamma': 6.851738448380771e-06, 'reg_alpha': 4.714325570420214e-08, 'reg_lambda': 1.1924497858414252e-05, 'min_child_weight': 8}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:02,796] Trial 39 finished with value: 0.5864826155940477 and parameters: {'n_estimators': 452, 'max_depth': 4, 'learning_rate': 0.028546284133487667, 'subsample': 0.6134886450463509, 'colsample_bytree': 0.9688539075093638, 'gamma': 0.00010366164255144897, 'reg_alpha': 0.16223539722242336, 'reg_lambda': 8.611317028929766e-06, 'min_child_weight': 6}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:06,194] Trial 40 finished with value: 0.560070002813733 and parameters: {'n_estimators': 745, 'max_depth': 5, 'learning_rate': 0.05859109726659844, 'subsample': 0.50420822569441, 'colsample_bytree': 0.8829594743128168, 'gamma': 0.2704474265268164, 'reg_alpha': 1.1095745940601158e-08, 'reg_lambda': 5.861830135186965e-07, 'min_child_weight': 2}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:08,473] Trial 41 finished with value: 0.5842928365463893 and parameters: {'n_estimators': 697, 'max_depth': 3, 'learning_rate': 0.0129164362572847, 'subsample': 0.7130681573438755, 'colsample_bytree': 0.9351710159553401, 'gamma': 0.005534082044237373, 'reg_alpha': 2.1433936407079937e-06, 'reg_lambda': 5.880117653145276e-05, 'min_child_weight': 6}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:10,612] Trial 42 finished with value: 0.588514270331346 and parameters: {'n_estimators': 622, 'max_depth': 3, 'learning_rate': 0.016243802326453533, 'subsample': 0.5633964825829346, 'colsample_bytree': 0.7506648560709075, 'gamma': 0.002020774562463822, 'reg_alpha': 5.34583633648836e-07, 'reg_lambda': 0.00033312451692287903, 'min_child_weight': 5}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:13,133] Trial 43 finished with value: 0.5551854406640577 and parameters: {'n_estimators': 615, 'max_depth': 4, 'learning_rate': 0.14791971998708836, 'subsample': 0.5593680310855094, 'colsample_bytree': 0.7500535420522977, 'gamma': 0.00037232761821286056, 'reg_alpha': 1.8739682362501356e-07, 'reg_lambda': 0.009599903522129121, 'min_child_weight': 4}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:15,697] Trial 44 finished with value: 0.587608414909281 and parameters: {'n_estimators': 768, 'max_depth': 3, 'learning_rate': 0.014761166366609556, 'subsample': 0.5367954660482029, 'colsample_bytree': 0.8289026716625546, 'gamma': 0.001819818688085894, 'reg_alpha': 6.237371667431852e-07, 'reg_lambda': 7.192724122347818e-06, 'min_child_weight': 5}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:17,055] Trial 45 finished with value: 0.5845367923032427 and parameters: {'n_estimators': 406, 'max_depth': 3, 'learning_rate': 0.037909442520241136, 'subsample': 0.5788314892621464, 'colsample_bytree': 0.7908525588194808, 'gamma': 2.4482414814615803e-05, 'reg_alpha': 4.2232261685289377e-08, 'reg_lambda': 0.0017167004298020182, 'min_child_weight': 9}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:19,348] Trial 46 finished with value: 0.5456238395695117 and parameters: {'n_estimators': 532, 'max_depth': 5, 'learning_rate': 0.29407704680698615, 'subsample': 0.5245572120728631, 'colsample_bytree': 0.9601801886925243, 'gamma': 0.9005078507481676, 'reg_alpha': 1.0786448232090749e-07, 'reg_lambda': 0.00020402731741829943, 'min_child_weight': 7}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:21,339] Trial 47 finished with value: 0.5815762040106557 and parameters: {'n_estimators': 474, 'max_depth': 4, 'learning_rate': 0.01024503281327549, 'subsample': 0.5740706633095594, 'colsample_bytree': 0.7181665357706439, 'gamma': 0.02420127850848434, 'reg_alpha': 1.124592757538995e-06, 'reg_lambda': 0.06318165372472333, 'min_child_weight': 3}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:26,351] Trial 48 finished with value: 0.5638184816960441 and parameters: {'n_estimators': 851, 'max_depth': 7, 'learning_rate': 0.07636732844969019, 'subsample': 0.8904515098064334, 'colsample_bytree': 0.9052972067615694, 'gamma': 2.3477894384585188e-08, 'reg_alpha': 0.06276426467406641, 'reg_lambda': 0.2705239431010341, 'min_child_weight': 18}. Best is trial 27 with value: 0.5905333910082331.
# [I 2025-11-22 02:41:28,788] Trial 49 finished with value: 0.582977207991598 and parameters: {'n_estimators': 619, 'max_depth': 4, 'learning_rate': 0.021514768661294655, 'subsample': 0.8326414929027007, 'colsample_bytree': 0.8770643226262936, 'gamma': 3.2045328353881187e-06, 'reg_alpha': 4.6534534089222227e-07, 'reg_lambda': 5.720184066039162e-05, 'min_child_weight': 8}. Best is trial 27 with value: 0.5905333910082331.
# Лучшие параметры: {'n_estimators': 557, 'max_depth': 4, 'learning_rate': 0.014248074439395327, 'subsample': 0.6965177940657781, 'colsample_bytree': 0.8477507656565151, 'gamma': 0.08716186049380047, 'reg_alpha': 2.985738729785991e-06, 'reg_lambda': 0.0044089064287612615, 'min_child_weight': 7}
# Лучший F1: 0.5905333910082331

# %%
mlflow.set_experiment("Customer_Churn")
params = {'n_estimators': 557, 
          'max_depth': 4, 
          'learning_rate': 0.015, 
          'subsample': 0.7,
          'colsample_bytree': 0.85, 
          'gamma': 0.09,
          'reg_alpha': 3e-06, 
          'reg_lambda': 0.005,
          'min_child_weight': 7}


scoring = ['roc_auc', 'f1', 'precision', 'recall']

XGBM_clf = XGBClassifier(**params)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name='XGBM'):
    mlflow.log_param("model", "XGBM")
    for param, value in params.items():
        mlflow.log_param(param, value)
   
    
    scores = cross_validate(XGBM_clf, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    XGBM_clf.fit(X, y)
    mlflow.xgboost.log_model(XGBM_clf, "XGBM")

pd.DataFrame(scores)
# Out:
# roc_auc: mean=0.846
# f1: mean=0.588
# precision: mean=0.654
# recall: mean=0.535
# 2025/11/22 02:51:49 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/22 02:51:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  0.418118    0.034182      0.858414  0.619677        0.687296     0.564171
# 1  0.380859    0.025977      0.842960  0.598854        0.645062     0.558824
# 2  0.666652    0.028268      0.854627  0.584934        0.653465     0.529412
# 3  0.371490    0.032752      0.833063  0.552036        0.631034     0.490617
# 4  0.342271    0.025459      0.840652  0.586156        0.652459     0.532086

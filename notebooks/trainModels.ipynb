# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score, cross_val_predict, StratifiedKFold, cross_validate
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score, make_scorer
import mlflow
import mlflow.sklearn

import optuna

# %% [markdown]
# # Logistic regression (baseLine)

# %%
data = pd.read_csv(r"..\data/preprocessed_dummy_Data.csv",)
X, y = data.drop(['Churn'], axis=1), data['Churn']

# %% [markdown]
# ## Simple Solution

# %%
mlflow.set_experiment("Customer_Churn")

scoring = ['roc_auc', 'f1', 'precision', 'recall']

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(class_weight='balanced', random_state=42))
])

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name="basicRegression"):
    mlflow.log_param("model", "base_LogisticRegression")
    mlflow.log_param("class_weight", "balanced")
    mlflow.log_param("solver", "lbfgs")
    
    scores = cross_validate(pipeline, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    pipeline.fit(X, y)
    mlflow.sklearn.log_model(pipeline, "logreg_pipeline")

pd.DataFrame(scores)
# Out:
# 2025/11/21 01:29:31 INFO mlflow.tracking.fluent: Experiment with name 'Customer_Churn' does not exist. Creating a new experiment.
# 2025/11/21 01:29:31 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# roc_auc: mean=0.842
# f1: mean=0.625
# precision: mean=0.515
# recall: mean=0.796
# 2025/11/21 01:29:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  0.018234    0.015012      0.851576  0.638478        0.527972     0.807487
# 1  0.025866    0.013799      0.842649  0.635802        0.516722     0.826203
# 2  0.023190    0.013704      0.857488  0.628030        0.518261     0.796791
# 3  0.020062    0.016475      0.824710  0.605096        0.500879     0.764075
# 4  0.022173    0.014248      0.835542  0.619600        0.511304     0.786096

# %% [markdown]
# ## Tuned logistic regression

# %%
def objective(trial):
   
    C = trial.suggest_float('C', 1, 100, log=True)   
    penalty = trial.suggest_categorical('penalty', ['l1', 'l2'])
       # Подбор class_weight
    cw_option = trial.suggest_categorical('class_weight_option', ['none', 'balanced', 'custom'])
    if cw_option == 'none':
        class_weight = None
    elif cw_option == 'balanced':
        class_weight = 'balanced'
    else:
        # пример: w0=1, w1=trial от 1 до 5
        w1 = trial.suggest_float('custom_weight_1', 1.0, 5.0)
        class_weight = {0: 1.0, 1: w1}
        
    solver = 'liblinear' if penalty == 'l1' else 'lbfgs'   
    
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('logreg', LogisticRegression(C=C, penalty=penalty, solver=solver, max_iter=1000, random_state=42, class_weight=class_weight))
    ])
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    
    scores = cross_val_score(pipeline, X, y, cv=skf, scoring='f1')
    
    return scores.mean()

# %%
study = optuna.create_study(direction='maximize')  
study.optimize(objective, n_trials=100)
# Out:
# [I 2025-11-21 01:20:17,539] A new study created in memory with name: no-name-17405976-5fda-4e65-b11c-81deb0975029
# [I 2025-11-21 01:20:21,644] Trial 0 finished with value: 0.6157540130670005 and parameters: {'C': 64.00464255804783, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.634901170414534}. Best is trial 0 with value: 0.6157540130670005.
# [I 2025-11-21 01:20:24,859] Trial 1 finished with value: 0.5735322001046615 and parameters: {'C': 20.178919587228144, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 0 with value: 0.6157540130670005.
# [I 2025-11-21 01:20:26,737] Trial 2 finished with value: 0.5730383889625864 and parameters: {'C': 3.7589958530585266, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 0 with value: 0.6157540130670005.
# [I 2025-11-21 01:20:26,854] Trial 3 finished with value: 0.5732755179719893 and parameters: {'C': 14.752164643576586, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 0 with value: 0.6157540130670005.
# [I 2025-11-21 01:20:30,204] Trial 4 finished with value: 0.612715805009859 and parameters: {'C': 2.2721346170329357, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 3.832322659292054}. Best is trial 0 with value: 0.6157540130670005.
# [I 2025-11-21 01:20:32,346] Trial 5 finished with value: 0.6306164307438901 and parameters: {'C': 2.1989374375124067, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.0204415270971343}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:35,338] Trial 6 finished with value: 0.5731126060375265 and parameters: {'C': 19.289616615301455, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:35,461] Trial 7 finished with value: 0.617396296699051 and parameters: {'C': 66.93332296975994, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 3.5644307706001337}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:36,354] Trial 8 finished with value: 0.5924261888790737 and parameters: {'C': 2.1916942253602136, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.1045081952083682}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:37,121] Trial 9 finished with value: 0.62684619771011 and parameters: {'C': 1.394058124148751, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:37,264] Trial 10 finished with value: 0.6243300596258863 and parameters: {'C': 5.987400187349806, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:38,125] Trial 11 finished with value: 0.6268440186092776 and parameters: {'C': 1.0214211510711328, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:38,995] Trial 12 finished with value: 0.62684619771011 and parameters: {'C': 1.0485154724566481, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:40,918] Trial 13 finished with value: 0.6254243678798276 and parameters: {'C': 2.4133680607682497, 'penalty': 'l1', 'class_weight_option': 'balanced'}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,045] Trial 14 finished with value: 0.6283950662255469 and parameters: {'C': 6.249884434988472, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.8656774027021443}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,172] Trial 15 finished with value: 0.6260174981644452 and parameters: {'C': 6.619417839447729, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.7835875924209423}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,294] Trial 16 finished with value: 0.629210392118139 and parameters: {'C': 6.539069091797525, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.2979372807051184}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,422] Trial 17 finished with value: 0.6266740063652368 and parameters: {'C': 9.88645740251685, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.514725979855097}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,550] Trial 18 finished with value: 0.6267417128624629 and parameters: {'C': 38.27887525468581, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.5778977852535734}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,682] Trial 19 finished with value: 0.6294229880198516 and parameters: {'C': 3.6936763471755514, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.9326735058335078}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,809] Trial 20 finished with value: 0.6023947307421371 and parameters: {'C': 3.4818597429804354, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 4.622416043396672}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:41,935] Trial 21 finished with value: 0.6293244664451481 and parameters: {'C': 4.196725017294456, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.8950533490948944}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:42,060] Trial 22 finished with value: 0.6012027627135597 and parameters: {'C': 3.7399784967494, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.2414900704148455}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:42,183] Trial 23 finished with value: 0.6259753782625409 and parameters: {'C': 1.7195586331293606, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.7852883362370267}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:42,309] Trial 24 finished with value: 0.6232532749483335 and parameters: {'C': 3.150959368033704, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 3.034385679881267}. Best is trial 5 with value: 0.6306164307438901.
# [I 2025-11-21 01:20:42,425] Trial 25 finished with value: 0.6319574420362934 and parameters: {'C': 4.817062413297177, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0733252745930923}. Best is trial 25 with value: 0.6319574420362934.
# [I 2025-11-21 01:20:42,555] Trial 26 finished with value: 0.6233036978919182 and parameters: {'C': 10.290875553753567, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.901969693799792}. Best is trial 25 with value: 0.6319574420362934.
# [I 2025-11-21 01:20:42,688] Trial 27 finished with value: 0.6179835445733877 and parameters: {'C': 1.6577234085654007, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.5037775494403296}. Best is trial 25 with value: 0.6319574420362934.
# [I 2025-11-21 01:20:44,981] Trial 28 finished with value: 0.5730383889625864 and parameters: {'C': 4.828426289410357, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 25 with value: 0.6319574420362934.
# [I 2025-11-21 01:20:48,878] Trial 29 finished with value: 0.6292712639640825 and parameters: {'C': 10.062263095830605, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.2129306619173588}. Best is trial 25 with value: 0.6319574420362934.
# [I 2025-11-21 01:20:49,007] Trial 30 finished with value: 0.6229662128960023 and parameters: {'C': 2.7058898826366256, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.944464910098496}. Best is trial 25 with value: 0.6319574420362934.
# [I 2025-11-21 01:20:49,138] Trial 31 finished with value: 0.6332089333761317 and parameters: {'C': 5.024919103797885, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0645017860930523}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:49,274] Trial 32 finished with value: 0.630216249139346 and parameters: {'C': 4.9517512912912975, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.1624331522823343}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:49,403] Trial 33 finished with value: 0.629421806833189 and parameters: {'C': 8.189157176205208, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.3050987816640593}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:49,518] Trial 34 finished with value: 0.5736369612808384 and parameters: {'C': 5.264456178837164, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:52,823] Trial 35 finished with value: 0.6175179788011074 and parameters: {'C': 7.965039732139151, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.5342862158370656}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:52,953] Trial 36 finished with value: 0.5732755179719893 and parameters: {'C': 12.967795921574167, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:57,183] Trial 37 finished with value: 0.6269060154281856 and parameters: {'C': 16.531595296638518, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 2.6163798456783756}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:20:57,365] Trial 38 finished with value: 0.631228135647613 and parameters: {'C': 36.61121920340256, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.131328918082292}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:21:01,591] Trial 39 finished with value: 0.5732648736772126 and parameters: {'C': 61.77617294871841, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:21:01,729] Trial 40 finished with value: 0.6140485744340125 and parameters: {'C': 49.138048720384454, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.469659057786263}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:21:01,943] Trial 41 finished with value: 0.6321828746630499 and parameters: {'C': 24.560978315348024, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.114381302747546}. Best is trial 31 with value: 0.6332089333761317.
# [I 2025-11-21 01:21:02,094] Trial 42 finished with value: 0.6336829400423047 and parameters: {'C': 32.514063443302604, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0601019447356177}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:02,248] Trial 43 finished with value: 0.6284092246644585 and parameters: {'C': 27.832717243011242, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.3864226429765902}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:02,428] Trial 44 finished with value: 0.6271145559445305 and parameters: {'C': 22.513978168892436, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.695261896557479}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:02,621] Trial 45 finished with value: 0.6249915516431432 and parameters: {'C': 84.04202157473337, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:02,785] Trial 46 finished with value: 0.6246627852538955 and parameters: {'C': 31.136216688519067, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.6500475599437645}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:02,934] Trial 47 finished with value: 0.6188666456853213 and parameters: {'C': 42.51339595594644, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 3.2480750051662914}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:03,101] Trial 48 finished with value: 0.6248584954358256 and parameters: {'C': 22.913283194778103, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:03,279] Trial 49 finished with value: 0.6301464963202553 and parameters: {'C': 27.356007775302498, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0024002925456195}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:03,458] Trial 50 finished with value: 0.6311868098870159 and parameters: {'C': 54.29883744456355, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.1250753170180148}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:03,650] Trial 51 finished with value: 0.6313700973599106 and parameters: {'C': 48.998317081738705, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.1013332885551326}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:03,996] Trial 52 finished with value: 0.6021132121972876 and parameters: {'C': 97.60115790084994, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.2927056887255022}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:04,288] Trial 53 finished with value: 0.6297790922434418 and parameters: {'C': 36.24592254837087, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.16473949656218}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:04,523] Trial 54 finished with value: 0.624793286766767 and parameters: {'C': 72.3979210210105, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.6716004142396583}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:04,729] Trial 55 finished with value: 0.6286871262537049 and parameters: {'C': 46.90374046014006, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.4094970815230026}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:04,921] Trial 56 finished with value: 0.6248584954358256 and parameters: {'C': 35.48809267759583, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:05,198] Trial 57 finished with value: 0.6313573054751541 and parameters: {'C': 18.572985591254266, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.042580437429635}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:05,426] Trial 58 finished with value: 0.6082924761793617 and parameters: {'C': 13.098892718927722, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 4.160122213284089}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:05,620] Trial 59 finished with value: 0.5784471573142435 and parameters: {'C': 18.418719209181223, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.0208631002637933}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:05,792] Trial 60 finished with value: 0.5732755179719893 and parameters: {'C': 21.363551890392195, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:05,972] Trial 61 finished with value: 0.6291375112420807 and parameters: {'C': 26.33673294339754, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.9973836456846337}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:06,170] Trial 62 finished with value: 0.6264362879332238 and parameters: {'C': 32.16166519133499, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.7771970714279022}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:06,374] Trial 63 finished with value: 0.6321232003174162 and parameters: {'C': 15.877146041501033, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.04358164274968}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:06,561] Trial 64 finished with value: 0.6286082958349549 and parameters: {'C': 14.59026272029714, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.427705097210503}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:06,759] Trial 65 finished with value: 0.6289278593357585 and parameters: {'C': 18.591640859856955, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.956999485254464}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:06,978] Trial 66 finished with value: 0.6255431571777921 and parameters: {'C': 11.966055476544694, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.797622898564864}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:07,175] Trial 67 finished with value: 0.6268505051108291 and parameters: {'C': 8.423724371685934, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.809953791187602}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:07,349] Trial 68 finished with value: 0.6282779079867457 and parameters: {'C': 15.20488329457518, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.4616895216100323}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:07,548] Trial 69 finished with value: 0.6248584954358256 and parameters: {'C': 24.670495675319692, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:07,737] Trial 70 finished with value: 0.6313799643397513 and parameters: {'C': 3.026043409783678, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0184607063714104}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:08,014] Trial 71 finished with value: 0.6304963525591035 and parameters: {'C': 2.851851721709913, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.9930554170568915}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:08,214] Trial 72 finished with value: 0.6293014924495067 and parameters: {'C': 1.8145842610881802, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.308462623421825}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:08,392] Trial 73 finished with value: 0.6259323905229177 and parameters: {'C': 7.378688952249918, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.717857134863722}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:08,562] Trial 74 finished with value: 0.6323260551881184 and parameters: {'C': 4.392378815238389, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0825577799539046}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:08,755] Trial 75 finished with value: 0.6293253702331871 and parameters: {'C': 4.6325744099528805, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.225948498758549}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:08,916] Trial 76 finished with value: 0.6288662087461594 and parameters: {'C': 4.17373058824726, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.8691452784178821}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:12,099] Trial 77 finished with value: 0.5734783043206442 and parameters: {'C': 6.111765282248896, 'penalty': 'l1', 'class_weight_option': 'none'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:12,262] Trial 78 finished with value: 0.6273699783468993 and parameters: {'C': 3.2104806087818805, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.5885440792401457}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:12,427] Trial 79 finished with value: 0.6085287330822947 and parameters: {'C': 5.500902978583462, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.39276634008403}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:12,582] Trial 80 finished with value: 0.6302994575015172 and parameters: {'C': 2.276584123992245, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.278314035706347}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:12,734] Trial 81 finished with value: 0.6325878782792711 and parameters: {'C': 1.9979581401819826, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.063002639189423}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:12,888] Trial 82 finished with value: 0.63118465765567 and parameters: {'C': 1.3524534217856368, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.100168120335479}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:13,067] Trial 83 finished with value: 0.6302086117849521 and parameters: {'C': 2.0676833603899074, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.8832769474517181}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:13,213] Trial 84 finished with value: 0.6236762179705894 and parameters: {'C': 2.675263339016777, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.6353216767504817}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:13,362] Trial 85 finished with value: 0.6295872647938806 and parameters: {'C': 4.212883854977835, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.3030855659534244}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:13,511] Trial 86 finished with value: 0.6321561837632562 and parameters: {'C': 1.9850090364431991, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0664918626014073}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:14,442] Trial 87 finished with value: 0.6289430360460534 and parameters: {'C': 1.476173381882332, 'penalty': 'l1', 'class_weight_option': 'custom', 'custom_weight_1': 1.8544536468833115}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:14,597] Trial 88 finished with value: 0.5989048724939074 and parameters: {'C': 1.2035469637375056, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 4.854267314055691}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:14,756] Trial 89 finished with value: 0.6249999629998687 and parameters: {'C': 3.377316501354443, 'penalty': 'l2', 'class_weight_option': 'balanced'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:14,901] Trial 90 finished with value: 0.5734561736548855 and parameters: {'C': 1.8650974761925219, 'penalty': 'l2', 'class_weight_option': 'none'}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:15,053] Trial 91 finished with value: 0.6325232052773588 and parameters: {'C': 2.5276740097213843, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0592060676348374}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:15,239] Trial 92 finished with value: 0.6293835440725294 and parameters: {'C': 2.654607363587694, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.1916104561290526}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:15,402] Trial 93 finished with value: 0.6312166059001296 and parameters: {'C': 2.1533509048478394, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.0419900179999164}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:15,575] Trial 94 finished with value: 0.618303352695185 and parameters: {'C': 2.868860262881343, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.555422853474975}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:15,726] Trial 95 finished with value: 0.6301445774513004 and parameters: {'C': 3.7727239190290347, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.9278446279646162}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:15,885] Trial 96 finished with value: 0.627051086155139 and parameters: {'C': 2.3898104923292403, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.5126922913756267}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:16,074] Trial 97 finished with value: 0.6292288572675442 and parameters: {'C': 1.9299565087542134, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 2.325525152663052}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:16,294] Trial 98 finished with value: 0.6238323492357568 and parameters: {'C': 5.4697038479513225, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 1.729508461657947}. Best is trial 42 with value: 0.6336829400423047.
# [I 2025-11-21 01:21:16,492] Trial 99 finished with value: 0.6172955761588924 and parameters: {'C': 1.5372940009820248, 'penalty': 'l2', 'class_weight_option': 'custom', 'custom_weight_1': 3.392976083420077}. Best is trial 42 with value: 0.6336829400423047.

# %%
print("Best trial:")
trial = study.best_trial
print("  F1: {:.4f}".format(trial.value))
print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# Best trial:
#   F1: 0.6337
#   Params:
#     C: 32.514063443302604
#     penalty: l2
#     class_weight_option: custom
#     custom_weight_1: 2.0601019447356177

# %%
mlflow.set_experiment("Customer_Churn")

scoring = ['roc_auc', 'f1', 'precision', 'recall']

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('logreg', LogisticRegression(class_weight={0: 1.0, 1: 2}, random_state=42, C=32, penalty='l2'))
])

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

with mlflow.start_run(run_name='tunedRegression'):
    mlflow.log_param("model", "tuned_LogisticRegression")
    mlflow.log_param("class_weight", "custom, w2=2.0")
    mlflow.log_param("solver", "lbfgs")
    mlflow.log_param("C", "32.8")
    mlflow.log_param("penalty", "L2")
    
    scores = cross_validate(pipeline, X, y, cv=skf, scoring=scoring, return_train_score=False)
    
    for metric in scoring:
        mean_score = scores[f'test_{metric}'].mean()
        mlflow.log_metric(f"CV_{metric}_mean", mean_score)
        print(f"{metric}: mean={mean_score:.3f}")
    
    pipeline.fit(X, y)
    mlflow.sklearn.log_model(pipeline, "logreg_pipeline_tuned")

pd.DataFrame(scores)
# Out:
# 2025/11/21 01:29:39 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# roc_auc: mean=0.842
# f1: mean=0.630
# precision: mean=0.555
# recall: mean=0.728
# 2025/11/21 01:29:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
#    fit_time  score_time  test_roc_auc   test_f1  test_precision  test_recall
# 0  0.020784    0.012567      0.851431  0.646512        0.572016     0.743316
# 1  0.019981    0.015765      0.842644  0.645455        0.561265     0.759358
# 2  0.029173    0.014781      0.857359  0.646651        0.569106     0.748663
# 3  0.018884    0.015490      0.824847  0.599526        0.537155     0.678284
# 4  0.024504    0.014855      0.835449  0.609896        0.535354     0.708556
